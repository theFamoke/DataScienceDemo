# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.float_format', '{:.3f}'.format)
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
df= pd.read_csv('Movies.csv')#movies csv contains id of the movie,tittle,category of genre, year of release, country, number of views and percentage of cedit given for each movie
df
# Out:
#        Id                              Tittle                           Genre  \
# 0    a234                          The streak  sci-fi,fventureamily,adventure
# 1    j432                            The Hero                   drama, comedy
# 2    c642                         Family ties                    family,drama
# 3    f311                       Dancing Booth            sci-fi,drama, comedy
# 4    a576                           Saraphina                Crime, Adventure
# 5    c870  Long Zhii and the mysterious sword                   drama, comedy
# 6    a807                            SeaBoorn                thriller, comedy
# 7   t8700                     Over and Around                action,adventure
# 8   i7880                               Rajab             drama,family,action
# 9    a876                         Adventerous        sci-fi,fantasy,Adventure
# 10   i965                      Tripple Stages            action,crime,fantasy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  18 non-null     object
#  1   Tittle              18 non-null     object
#  2   Genre               18 non-null     object
#  3   Release Year        18 non-null     int64
#  4   Production company  18 non-null     object
#  5   Country             18 non-null     object
#  6   Views               18 non-null     object
#  7   Credits             18 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.3+ KB

# %%
df['Credits'].value_counts()
# Out:
# Credits
# 50%    2
# 23%    2
# 64%    2
# 22%    2
# 20%    1
# 45%    1
# 35%    1
# 7%     1
# 25%    1
# 53%    1
# 43%    1
# 65%    1
# 75%    1
# 36%    1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(30,5))
sns.countplot(x='Credits', data=df,edgecolor='black')
# Out:
# <Axes: xlabel='Credits', ylabel='count'>
